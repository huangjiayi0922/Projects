# %% [markdown]
# # An Exploratory Topical Analysis of Obama's Speeches Utilizing Text Analysis Techniques and Data Analysis and Visualizations
# ### By: Arvind Iyengar, Jiayi Huang, Parth Singhal

# %% [markdown]
# ## Research Topic:
#
# Is the political interest of the administration in charge of the executive branch consistent with the actions of the legislative branch, specifically in regards to budget allocation? Furthermore, could a difference/discrepancy between the actions of the legislative branch and the agenda of the excecutive branch be the result of the political affiliations of the two?
#
# We will use Obama's administration to test the correlation between the content of Obama's speeches and Congress's actual national spending in particular areas over the 8-year span, and then specifically look at the differences during three time periods:
#
# 1. 2009-2011: when the Democrats had majority control of both the House and the Senate
# 2. 2012-2014: when the Democrats had majority control of the Senate and the Republicans had majority control of the House
# 3. 2015-2016: when the Republicans had majority control of both the House and the Senate
#
# We will be comparing the consistency and correlation between Obama’s speeches and the national budget expenditure on 4 major national budget categories: National Defense, Employment, Education, and Health Care over the span of 2009 - 2016. Was the political interest of the Obama administration, expressed in Obama's speeches, consistent with the actions of the legislative branch during his two consecutive terms in regards to the allocation of the national budget as decided by Congress? To answer this question, we will compare the prevalence of topics in Obama's speeches with the proportions of national budget expenses for the corresponding category.
#
# ## Research Questions:
#
# **Part 1**: Was the political interest of the Obama administration, expressed in Obama's speeches, consistent with the actions of the legislative branch during his two consecutive terms in regards to the allocation of the national budget as decided by Congress?
#
# **Part 2**: If any inconsistency does exist between the agenda of the executive adminstration and the legislative branch, are the inconsistencies associated with a difference in the political affiliations of the two branches of government?
#
# ## Corpus:
#
# We will be using a collection of speeches delivered by former President Barack Obama during years 2009 - 2016, as our corpus. Additionally, we will be using annual national budget data from the years 2009 - 2016. Our corpus is appropriate and consistent with our topic of research and analysis, since it is directly drawn from presidential speeches and national budget data from years 2009 - 2016. We also adjusted the speech dates based on the fiscal year to align with the budget data.
#
# ## Statistical & Computational Methods and Techniques:
#
# Topic modeling, bags of words, measuring correlation, hypothesis testing, bootstrap and data visualizations including barcharts, lineplots, and scatterplots. Computational text analysis methods make sense for this task as we will deal with large streams of data (speeches), and we want to look at the usage of 'bag of words' under specified categories. This requires counting occurence and frequency (normalized) of each word. Furthermore, combining speech data with budget data will also require integrating text, hypothesis, and bootstrap analysis techniques in our work which inherently require computation.
#
#
# ## Sources:
#
# Obama Speeches:
# http://www.americanrhetoric.com/barackobamaspeeches.htm
#
# Federal budget grouped by categories:
# http://federal-budget.insidegov.com/l/119/2016#Spending&s=47xnQz
#
# Budget Data:
# https://obamawhitehouse.archives.gov/omb/budget/Historicals

# %%
# !pip install requests
# Out:
# Requirement already satisfied (use --upgrade to upgrade): requests in /Users/JiayiHuang/anaconda/lib/python3.5/site-packages
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Import packages
import pandas
import numpy as np
import os
import nltk
import requests
import string
from nltk.corpus import stopwords

import warnings
warnings.filterwarnings("ignore")

import scipy

from datetime import datetime
from datascience import *

from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.decomposition import LatentDirichletAllocation # for topic modeling

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Loading dataset.csv
#
# The speeches dataset that is used in this notebook contains transcriptions of speeches given by President Obama between the years of 2009 and 2016 stored in `dataset.csv`, which was generated using a web scrapper. You must have `dataset.csv` in your current working directory for this code to work.

# %%
speeches = pandas.read_csv('dataset.csv').dropna(subset = ['Speeches'])
speeches
# Out:
#           Dates                                           Speeches
# 0    2009-01-08  Let me begin by thanking George Mason Universi...
# 1    2009-01-18   Hello America! I want to thank all the speake...
# 2    2009-01-20  [Chief Justice John G.  Roberts administers th...
# 3    2009-01-24  click for pdfWe begin this year and this Admin...
# 4    2009-01-26  Mr.  Melhem: Mr.  President, thank you for thi...
# 5    2009-02-04  Thank you, Tim, for your hard work on this iss...
# 6    2009-02-09  PRESIDENT OBAMA: Good evening, everybody.  Ple...
# 7    2009-02-12  Thank you.  Pease, be seated.  Thank you, very...
# 8    2009-02-24  Madame Speaker, Mr.  Vice President, Members o...
# 9    2009-02-27  Thank you very much.  To General Haley for the...
# 10   2009-03-10  Please, everybody have a seat.  Thank you for ...
# 11   2009-04-02  Good afternoon, or good evening -- we're runni...
# 12   2009-04-03  Thank you so much.  Good afternoon.  Bon après...
# 13   2009-04-05  *Thank you so much.  Thank you for this wonder...
# 14   2009-04-06  Mr.  Speaker, Madam Deputy Speaker, distinguis...
# 15   2009-04-07  Thank you. Thank you, guys. Let me say Multina...
# 16   2009-04-14  Well, to President DeGioia, thank you so much ...
# 17   2009-04-20  Thank you for the extraordinary welcome.  And ...
# 18   2009-04-23  Thank you very much.  To Sara Bloomfield, for ...
# 19   2009-05-09    Plug-in required for flash audio   var so = ...
# 20   2009-05-18  President Obama: Thank you very much.  Thank y...
# 21   2009-05-21  Good morning, everybody.  Please be seated.  T...
# 22   2009-05-29  We meet today at a transformational moment -- ...
# 23   2009-06-04   Thank you so much.  Good afternoon.  I am hon...
# 24   2009-06-04  Chancellor Merkel and I have just finished our...
# 25   2009-06-05  Good afternoon.  Thank you, President Sarkozy,...
# 26   2009-06-15  Thank you so much.  Please, everybody, be seat...
# 27   2009-06-23   Good afternoon, everybody. Today I want to st...
# 28   2009-06-23  Good afternoon, everybody.  Today, I want to s...
# 29   2009-07-07  Good morning.  It is a great honor for me to j...
# ..          ...                                                ...
# 376  2016-07-16  Four days ago, this community was shaken by an...
# 377  2016-07-27  Hello, America! Hello, Democrats! So, twelve y...
# 378  2016-08-04  Good afternoon, everybody.  I just met again w...
# 379  2016-08-23  Well, to begin with, I just want to say thank ...
# 380  2016-09-05  Good evening, everybody.  Let me begin by than...
# 381  2016-09-06  President Obama: Thank you so much.  Thank you...
# 382  2016-09-08  Good afternoon, everybody.  Once again, I want...
# 383  2016-09-11  Good morning.  Scripture tells us, “Let not st...
# 384  2016-09-19  Good morning, everybody.  I want to say a few ...
# 385  2016-09-20  Mr.  President; Mr.  Secretary General; fellow...
# 386  2016-09-24  James Baldwin once wrote, For while the tale o...
# 387  2016-09-30  Zvia, Yoni, Chemi and generations of the Peres...
# 388  2016-11-09  Good afternoon, everybody. Yesterday, before v...
# 389  2016-11-10  President Obama: Well, I just had the opportun...
# 390  2016-11-14  Hello, everybody.  Hello, hello. Hello, everyb...
# 391  2016-11-16  Hello, Greece!  Yia sas!  Kalispera!   To the ...
# 392  2016-11-17  Chancellor Merkel: Ladies and gentlemen, I'm d...
# 393  2016-11-20  President Obama: Hola Peru!  Asu!  Muchas grac...
# 394  2016-11-20  Good evening, everybody.  Let me begin by than...
# 395  2016-12-04  Well, good evening, everybody.  On behalf of M...
# 396  2016-12-06  Good afternoon, everybody.  I was just told th...
# 397  2016-12-16  Good afternoon.  This is the most wonderful pr...
# 398  2016-12-27  President Obama: Prime Minister Abe, on behalf...
# 399  2017-01-04  Well, good afternoon.  It turns out these are ...
# 400  2017-01-06  President Obama: Thank you.  Good morning. Ms....
# 401  2017-01-10  My fellow Americans:Michelle and I have been s...
# 402  2017-01-12  Welcome to the White House, everybody.  As I h...
# 403  2017-01-17  They said this day would never come. 1,2Here i...
# 404  2017-01-18  Good afternoon, everybody.  Let me start out b...
# 405  2017-01-20  Michelle and I, we've really been milking this...
#
# [402 rows x 2 columns]

# %% [markdown]
# **Data Structure**: As we can see, our dataframe has three columns. The first one contains the date of each entry of speech given by Obama in the Date string format, the second one contains the actual speeches in strings as well. We have 402 speeches in total.

# %% [markdown]
# ### Loading Budget Data
#
# The national budget dataset that is used in this notebook contains budget data from 2009 to 2016, ordered by fiscal year, in `budget_data.xlsx`, which was found in a federal website. You must have `budget_data.xlsx` in your current working directory for this code to work.
#
# While the data is loaded, we take a couple of pre-processing steps to create four distinct supercategories which will be described in a later part of this notebook. To do this, we made the following changes to the initial dataset:
#
# - Combined National Defense and International Affairs to form 'National Defense' budget category.
#
# - Combined Income Security, Social Security, and Veteran Affairs to form 'Employment' budget category.
#
# - Combined Healthcare and Medicare to form 'Health' budget category.
#
# We also added in the proportions (which is simply the total spending per category divided by the Total federal outlay) to make later calculations easier.

# %%
budget_data = pandas.read_excel("budget_data.xlsx", sep = '\t', encoding = 'utf-8', index_col=0)
budget_data = Table.from_df(budget_data.drop([budget_data.index[0]]).T)
budget_data['National Defense Overall'] = budget_data['National Defense'] + budget_data['International Affairs']
budget_data['Employment/Social_Security'] = budget_data['Income Security'] + budget_data['Social Security'] + budget_data['Veterans Benefits and Services']
budget_data['Health_Overall'] = budget_data['Health'] + budget_data['Medicare']
budget_data = budget_data.drop('Human resources', 'Health', 'Medicare', 'Income Security', 
                 'Social Security', '(On-budget)', '(Off-budget)', 'National Defense', 'International Affairs',
                              'Veterans Benefits and Services')
budget_data = budget_data.relabeled('Education, Training, Employment, and Social Services', 'Education')
budget_data = budget_data.relabeled('Health_Overall', 'Health')
budget_data = budget_data.relabeled('National Defense Overall', 'National Defense')
budget_data = budget_data.select(2, 4, 0, 3, 1)
budget_data['National Defense prop'] = budget_data['National Defense'] / budget_data['Total federal outlay']
budget_data['Employment prop'] = budget_data['Employment/Social_Security'] / budget_data['Total federal outlay']
budget_data['Education prop'] = budget_data['Education'] / budget_data['Total federal outlay']
budget_data['Health Care prop'] = budget_data['Health'] / budget_data['Total federal outlay']
budget_data = budget_data.with_column("Year", [i for i in range(2009, 2017)]).select(9,5,6,7,8,0,3,2,1,4)
budget_data
# Out:
# Year | National Defense prop | Employment prop | Education prop | Health Care prop | National Defense | Employment/Social_Security | Education | Health      | Total federal outlay
# 2009 | 0.234187              | 0.372864        | 0.0226709      | 0.21731          | 823793           | 1.31162e+06                | 79749     | 764428      | 3.51768e+06
# 2010 | 0.250944              | 0.415765        | 0.0371985      | 0.237398         | 867533           | 1.43733e+06                | 128598    | 820704      | 3.45708e+06
# 2011 | 0.245597              | 0.403921        | 0.0280964      | 0.238175         | 884899           | 1.45535e+06                | 101233    | 858157      | 3.60306e+06
# 2012 | 0.242074              | 0.406912        | 0.0256783      | 0.231424         | 856205           | 1.43923e+06                | 90823     | 818535      | 3.53695e+06
# 2013 | 0.236956              | 0.431014        | 0.0210754      | 0.247823         | 818601           | 1.489e+06                  | 72808     | 856141      | 3.45465e+06
# 2014 | 0.222602              | 0.431758        | 0.0258449      | 0.262723         | 780469           | 1.51379e+06                | 90615     | 921137      | 3.50611e+06
# 2015 | 0.205766              | 0.421966        | 0.0330942      | 0.278835         | 758924           | 1.55633e+06                | 122061    | 1.02842e+06 | 3.68829e+06
# 2016 | 0.201965              | 0.413989        | 0.028834       | 0.283748         | 798025           | 1.6358e+06                 | 113932    | 1.12118e+06 | 3.95131e+06

# %% [markdown]
# **Data Structure**: As we can see, our cleaned, finalized table has only 5 columns: the first is the year and the remaining four are the proportions of the national budget put towards 4 different supercategories, as will be discussed in a later part of the notebook.

# %% [markdown]
# ### Tokenizing Our Speeches
#
# The following code tokenizes each speech and removes unnecessary tokens, such as stop words and tokens that contain numbers, that detract from identifying certain topics in our speeches. It then adds a column to the table that contains the tokenized versions of the speeches.

# %%
bad_tokens = list(string.punctuation) + ["...", "--"] + stopwords.words('English')

split_tokens = [nltk.word_tokenize(str(text).lower()) for text in speeches['Speeches']]
tokenized_speeches = []
for list_of_tokens in split_tokens:
    list_of_good_tokens = [token for token in list_of_tokens if token not in bad_tokens]
    list_of_good_tokens = [token for token in list_of_good_tokens if not any(char.isdigit() for char in token)]
    tokenized_speeches += [list_of_good_tokens]

speeches['Speeches Tokenized'] = [" ".join(text) for text in tokenized_speeches]

speeches
# Out:
#           Dates                                           Speeches  \
# 0    2009-01-08  Let me begin by thanking George Mason Universi...
# 1    2009-01-18   Hello America! I want to thank all the speake...
# 2    2009-01-20  [Chief Justice John G.  Roberts administers th...
# 3    2009-01-24  click for pdfWe begin this year and this Admin...
# 4    2009-01-26  Mr.  Melhem: Mr.  President, thank you for thi...
# 5    2009-02-04  Thank you, Tim, for your hard work on this iss...
# 6    2009-02-09  PRESIDENT OBAMA: Good evening, everybody.  Ple...
# 7    2009-02-12  Thank you.  Pease, be seated.  Thank you, very...
# 8    2009-02-24  Madame Speaker, Mr.  Vice President, Members o...
# 9    2009-02-27  Thank you very much.  To General Haley for the...
# 10   2009-03-10  Please, everybody have a seat.  Thank you for ...
# 11   2009-04-02  Good afternoon, or good evening -- we're runni...
# 12   2009-04-03  Thank you so much.  Good afternoon.  Bon après...
# 13   2009-04-05  *Thank you so much.  Thank you for this wonder...
# 14   2009-04-06  Mr.  Speaker, Madam Deputy Speaker, distinguis...
# 15   2009-04-07  Thank you. Thank you, guys. Let me say Multina...
# 16   2009-04-14  Well, to President DeGioia, thank you so much ...
# 17   2009-04-20  Thank you for the extraordinary welcome.  And ...
# 18   2009-04-23  Thank you very much.  To Sara Bloomfield, for ...
# 19   2009-05-09    Plug-in required for flash audio   var so = ...
# 20   2009-05-18  President Obama: Thank you very much.  Thank y...
# 21   2009-05-21  Good morning, everybody.  Please be seated.  T...
# 22   2009-05-29  We meet today at a transformational moment -- ...
# 23   2009-06-04   Thank you so much.  Good afternoon.  I am hon...
# 24   2009-06-04  Chancellor Merkel and I have just finished our...
# 25   2009-06-05  Good afternoon.  Thank you, President Sarkozy,...
# 26   2009-06-15  Thank you so much.  Please, everybody, be seat...
# 27   2009-06-23   Good afternoon, everybody. Today I want to st...
# 28   2009-06-23  Good afternoon, everybody.  Today, I want to s...
# 29   2009-07-07  Good morning.  It is a great honor for me to j...
# ..          ...                                                ...
# 376  2016-07-16  Four days ago, this community was shaken by an...
# 377  2016-07-27  Hello, America! Hello, Democrats! So, twelve y...
# 378  2016-08-04  Good afternoon, everybody.  I just met again w...
# 379  2016-08-23  Well, to begin with, I just want to say thank ...
# 380  2016-09-05  Good evening, everybody.  Let me begin by than...
# 381  2016-09-06  President Obama: Thank you so much.  Thank you...
# 382  2016-09-08  Good afternoon, everybody.  Once again, I want...
# 383  2016-09-11  Good morning.  Scripture tells us, “Let not st...
# 384  2016-09-19  Good morning, everybody.  I want to say a few ...
# 385  2016-09-20  Mr.  President; Mr.  Secretary General; fellow...
# 386  2016-09-24  James Baldwin once wrote, For while the tale o...
# 387  2016-09-30  Zvia, Yoni, Chemi and generations of the Peres...
# 388  2016-11-09  Good afternoon, everybody. Yesterday, before v...
# 389  2016-11-10  President Obama: Well, I just had the opportun...
# 390  2016-11-14  Hello, everybody.  Hello, hello. Hello, everyb...
# 391  2016-11-16  Hello, Greece!  Yia sas!  Kalispera!   To the ...
# 392  2016-11-17  Chancellor Merkel: Ladies and gentlemen, I'm d...
# 393  2016-11-20  President Obama: Hola Peru!  Asu!  Muchas grac...
# 394  2016-11-20  Good evening, everybody.  Let me begin by than...
# 395  2016-12-04  Well, good evening, everybody.  On behalf of M...
# 396  2016-12-06  Good afternoon, everybody.  I was just told th...
# 397  2016-12-16  Good afternoon.  This is the most wonderful pr...
# 398  2016-12-27  President Obama: Prime Minister Abe, on behalf...
# 399  2017-01-04  Well, good afternoon.  It turns out these are ...
# 400  2017-01-06  President Obama: Thank you.  Good morning. Ms....
# 401  2017-01-10  My fellow Americans:Michelle and I have been s...
# 402  2017-01-12  Welcome to the White House, everybody.  As I h...
# 403  2017-01-17  They said this day would never come. 1,2Here i...
# 404  2017-01-18  Good afternoon, everybody.  Let me start out b...
# 405  2017-01-20  Michelle and I, we've really been milking this...
#
#                                     Speeches Tokenized
# 0    let begin thanking george mason university ext...
# 1    hello america want thank speakers performers t...
# 2    chief justice john g. roberts administers oath...
# 3    click pdfwe begin year administration midst un...
# 4    mr. melhem mr. president thank opportunity rea...
# 5    thank tim hard work issue economic recovery ec...
# 6    president obama good evening everybody please ...
# 7    thank pease seated thank much madam speaker le...
# 8    madame speaker mr. vice president members cong...
# 9    thank much general haley outstanding work than...
# 10   please everybody seat thank wonderful introduc...
# 11   good afternoon good evening 're running little...
# 12   thank much good afternoon bon après-midi guten...
# 13   *thank much thank wonderful welcome thank peop...
# 14   mr. speaker madam deputy speaker distinguished...
# 15   thank thank guys let say multinational force i...
# 16   well president degioia thank much gracious int...
# 17   thank extraordinary welcome thanks prepared ci...
# 18   thank much sara bloomfield wonderful introduct...
# 19   plug-in required flash audio var new swfobject...
# 20   president obama thank much thank notre dame th...
# 21   good morning everybody please seated thank let...
# 22   meet today transformational moment moment hist...
# 23   thank much good afternoon honored timeless cit...
# 24   chancellor merkel finished tour buchenwald wan...
# 25   good afternoon thank president sarkozy prime m...
# 26   thank much please everybody seated thank much ...
# 27   good afternoon everybody today want start addr...
# 28   good afternoon everybody today want start addr...
# 29   good morning great honor join new economic sch...
# ..                                                 ...
# 376  four days ago community shaken evil hateful ac...
# 377  hello america hello democrats twelve years ago...
# 378  good afternoon everybody met national security...
# 379  well begin want say thank outstanding official...
# 380  good evening everybody let begin thanking pres...
# 381  president obama thank much thank sabaidii saba...
# 382  good afternoon everybody want thank government...
# 383  good morning scripture tells us “let steadfast...
# 384  good morning everybody want say words explosio...
# 385  mr. president mr. secretary general fellow del...
# 386  james baldwin wrote tale suffer delighted may ...
# 387  zvia yoni chemi generations peres family presi...
# 388  good afternoon everybody yesterday votes talli...
# 389  president obama well opportunity excellent con...
# 390  hello everybody hello hello hello everybody co...
# 391  hello greece yia sas kalispera government peop...
# 392  chancellor merkel ladies gentlemen 'm delighte...
# 393  president obama hola peru asu muchas gracias t...
# 394  good evening everybody let begin thanking pres...
# 395  well good evening everybody behalf michelle we...
# 396  good afternoon everybody told going last hail ...
# 397  good afternoon wonderful press conference year...
# 398  president obama prime minister abe behalf amer...
# 399  well good afternoon turns easier 're talking s...
# 400  president obama thank good morning ms. kliff g...
# 401  fellow americans michelle touched well-wishes ...
# 402  welcome white house everybody already delivere...
# 403  said day would never come something none prede...
# 404  good afternoon everybody let start saying sore...
# 405  michelle 've really milking goodbye thing beho...
#
# [402 rows x 3 columns]

# %% [markdown]
# ### Applying Topic Modeling To Our Tokenized Speeches To Generate Bags Of Words
#
# The following functions simplify the thought process that went behind implementing Latent-Dirchlet Allocation (a topic modeling algorithm) on the dataset. The functions are then applied to the dataset to produce a bag of words for relevant categories that are noticed in the federal budget and each bag of words generated is stored in the appropriate variable.

# %%
def print_top_words(model, feature_names, n_top_words):
    print("\nTopics in LDA model:")
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % int(int(topic_idx) ))
        print(", ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
    print()

def return_top_words(model, feature_names, n_top_words):
    top_words = [[feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]] for topic_idx, topic in enumerate(model.components_)]
    print("Done!")
    return top_words

def vectorize_text(text, stop_words='english'):
    print("Extracting tf features for LDA...")
    if not stop_words:
        tf_vectorizer = CountVectorizer(max_df=0.80, min_df=50, max_features=None)
    else:
        tf_vectorizer = CountVectorizer(max_df=0.80, min_df=50, max_features=None, stop_words=stop_words)
    return tf_vectorizer.fit_transform(text.values.astype('U')), tf_vectorizer.get_feature_names()

def fit_lda_model(tf, num_samples, num_topics):   
    print("Fitting LDA models with tf features, "
          "using %d samples and %d topics..."
          % (num_samples, num_topics))
    lda = LatentDirichletAllocation(n_topics=num_topics, max_iter=20,
                                    learning_method='online',
                                    learning_offset=80.,
                                    total_samples=num_samples,
                                    random_state=0)
    lda.fit(tf)
    return lda

# %%
num_samples = 10000
num_topics = 6
num_top_words = 50

tf, tf_feature_names = vectorize_text(speeches['Speeches Tokenized'])
lda = fit_lda_model(tf, num_samples, num_topics)
top_words = return_top_words(lda, tf_feature_names, num_top_words)
# Out:
# Extracting tf features for LDA...
# Fitting LDA models with tf features, using 10000 samples and 6 topics...
# Done!

# %%
national_defense_words = top_words[0]
print(national_defense_words)
# Out:
# ['iran', 'nuclear', 'security', 'israel', 'international', 'deal', 'weapons', 'sanctions', 'peace', 'government', 'intelligence', 'program', 'nations', 'region', 'war', 'weapon', 'community', 'clear', 'regime', 'place', 'military', 'allies', 'congress', 'state', 'continue', 'support', 'use', 'prevent', 'countries', 'national', 'partners', 'east', 'including', 'fact', 'peaceful', 'forward', 'actions', 'believe', 'issues', 'issue', 'minister', 'review', 'arms', 'efforts', 'action', 'resolve', 'prime', 'agreement', 'resolution', 'interests']

# %%
employment_words = top_words[1]
print(employment_words)
# Out:
# ['jobs', 'economy', 'energy', 'businesses', 'future', 'companies', 'tax', 'financial', 'plan', 'economic', 'year', 'reform', 'crisis', 'nation', 'business', 'oil', 'workers', 'clean', 'help', 'deficit', 'growth', 'dollars', 'government', 'families', 'investments', 'health', 'spending', 'recovery', 'money', 'cuts', 'budget', 'industry', 'small', 'debt', 'create', 'education', 'long', 'pay', 'credit', 'means', 'care', 'century', 'cut', 'reforms', 'responsibility', 'invest', 'ca', 'll', 'believe', 'private']

# %%
education_words = top_words[2]
print(education_words)
# Out:
# ['education', 'school', 'students', 'schools', 'college', 'teachers', 'children', 'child', 'high', 'student', 'parents', 'success', 'skills', 'community', 'standards', 'nation', 'learning', 'job', 'learn', 'century', 'training', 'future', 'responsibility', 'help', 'life', 'early', 'degree', 'year', 'earn', 'day', 'young', 'matter', 'class', 'dream', 'succeed', 'washington', 'science', 'quality', 'achievement', 'promise', 'means', 'prepare', 'outstanding', 'programs', 'chance', 'unless', 'career', 'best', 'opportunities', 'higher']

# %%
health_care_words = top_words[3]
print(health_care_words)
# Out:
# ['think', 'got', 'health', 'care', 'sure', 'lot', 'obama', 'question', 'things', 'better', 'everybody', 'insurance', 'thing', 'folks', 'making', 'll', 'congress', 'really', 'law', 'job', 'government', 'year', 'able', 'ca', 'look', 'working', 'help', 'getting', 'mr', 'hard', 'important', 'republicans', 'house', 'fact', 'actually', 'big', 'little', 'economy', 'long', 'day', 'kids', 'jobs', 'percent', 'money', 'families', 'start', 'point', 'place', 'state', 'republican']

# %%
intl_affairs_words = top_words[4]
print(intl_affairs_words)
# Out:
# ['think', 'countries', 'question', 'democracy', 'young', 'obama', 'russia', 'important', 'continue', 'change', 'believe', 'look', 'rights', 'future', 'progress', 'nations', 'global', 'government', 'sure', 'political', 'human', 'great', 'issues', 'better', 'able', 'things', 'trade', 'leaders', 'll', 'values', 'europe', 'mr', 'opportunity', 'women', 'international', 'security', 'help', 'respect', 'history', 'different', 'region', 'strong', 'policy', 'support', 'everybody', 'democratic', 'africa', 'society', 'true', 'feel']

# %%
veteran_affairs_words = top_words[5]
print(veteran_affairs_words)
# Out:
# ['nation', 'war', 'military', 'life', 'isil', 'men', 'women', 'iraq', 'god', 'lives', 'families', 'day', 'forces', 'security', 'home', 'troops', 'terrorists', 'afghanistan', 'love', 'children', 'faith', 'al', 'history', 'freedom', 'service', 'help', 'support', 'family', 'great', 'government', 'stand', 'nations', 'best', 'peace', 'power', 'including', 'man', 'justice', 'honor', 'long', 'force', 'fight', 'terrorist', 'qaeda', 'young', 'bless', 'veterans', 'change', 'better', 'protect']

# %% [markdown]
# ### Topic Modeling Algorithm Results:
#
# Although the results produced are notably random, due to our large sample size we tend to notice that the results converge on the following 6 topics associated with our National Budget:
#
# 0) National Defense
#
# 1) Employment
#
# 2) Education
#
# 3) Health Care
#
# 4) International Affairs
#
# 5) Veteran Affairs
#
# However, we also note that, in terms of budget, International Affairs tends to be associated with National Defense and Veteran Affairs is associated with Employment (due to Social Security incorporating both of these aspects). Therefore, as mentioned earlier, we combined those categories into budget supercategories during the pre-processing steps, and we will continue to combine these categories in upcoming steps. We employee those bags of words for our research due to two main purposes: 1) There is no appropirate existing bags of words for those categories on the Internet; 2) We want to use bags of words hat are localized to our corpus to make sure all the relevant words in the speeches are accounted for.

# %% [markdown]
# ### Visualizing The Prevalence Of Topics Over Obama's Entire Presidency
#
# The following code concatenates every speech together and then checks the number of times a word from the concatencated speeches are in a particular category for all categories that our topic modeling algorithm picked up on. Then, as described above, we combine the Veteran Affairs and Employment categories and the National Defense and International Affairs categories to come up with four supercategories associated with our budget. Finally, we normalize the word counts to come up with the proportion of all speeches associated with each of our topics, which we use as a measure of prevalence of each topic over the course of Obama's Entire Presidency.

# %%
all_speeches_wo_stopwords = (" ".join([word for word in speeches["Speeches Tokenized"]])).split()
num_words_in_national_defense = len([word for word in all_speeches_wo_stopwords if word in national_defense_words])
num_words_in_employment = len([word for word in all_speeches_wo_stopwords if word in employment_words])
num_words_in_education = len([word for word in all_speeches_wo_stopwords if word in education_words])
num_words_in_healthcare = len([word for word in all_speeches_wo_stopwords if word in health_care_words])
num_words_in_intl = len([word for word in all_speeches_wo_stopwords if word in intl_affairs_words])
num_words_in_veteran = len([word for word in all_speeches_wo_stopwords if word in veteran_affairs_words])
category_count = Table().with_columns(    
    'Categories', 
    make_array('National Defense',  'Employment', 'Education', 'Health Care'),
    'Number of Words',
    make_array(num_words_in_national_defense+num_words_in_intl, 
               num_words_in_employment+num_words_in_veteran, num_words_in_education, 
              num_words_in_healthcare)
)
category_summary = category_count.with_column('Proportion', category_count['Number of Words']/sum(category_count.column("Number of Words")))
category_summary.show()
category_summary.barh("Categories", "Proportion")
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Categories</th> <th>Number of Words</th> <th>Proportion</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>National Defense</td> <td>77254          </td> <td>0.348857  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Employment      </td> <td>70682          </td> <td>0.31918   </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Education       </td> <td>22394          </td> <td>0.101125  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Health Care     </td> <td>51119          </td> <td>0.230839  </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ### Findings:
#
# We see that National Defense is referred to the most, followed by Employment, Health Care, and Education. As we will see in a later part of this notebook, this is the same order of prevalence put towards these categories in the national budget, so we can see that our analysis is going in the right direction.

# %% [markdown]
# ### Visualizing The Prevalence Of Topics Each Fiscal Year Of Obama's Presidency And Comparing To Budget
#
# The following code creates a new table, df_w_topics, that utilizes the output of the LDA algorithm and the original speeches from the speeches dataset to plot the prevalence of topics over each fiscal year of Obama's presidency. We first use the date the speech was given to categorize each speech by its fiscal year and then find the mean prevalence of the topic over each fiscal year. This creates a table with an identical structure as the first five columns of our budget table (after the data cleaning done during the preparation step). We then use this information to plot the prevalence of topics over time in Obama's speeches against the actual budget data.

# %%
categories = [
    'National Defense',
    'Employment',
    'Education',
    'Health Care',
    'International Affairs',
    'Veteran Affairs'
]

topic_dist = lda.transform(tf)
topic_dist_df = pandas.DataFrame(topic_dist)
df_w_topics = topic_dist_df.join(speeches)
df_w_topics.columns = categories + list(df_w_topics.columns[6:])
    
df_w_topics = df_w_topics[pandas.notnull(df_w_topics['Dates'])]

fiscal_year = np.array([])
for date in  df_w_topics["Dates"]:
    year, month = int(date[:4]), int(date[5:7])
    if month >= 10:
        year += 1
    fiscal_year = np.append(fiscal_year, year)

df_w_topics["Dates"] = fiscal_year.astype(int)

# We remove dates associated with the fiscal year 2017 since Obama's presidency stops before it
df_w_topics = df_w_topics[df_w_topics["Dates"] != 2017]

df_w_topics.columns = [str(i) for i in df_w_topics.columns]
df_w_topics = Table.from_df(df_w_topics).relabeled("Dates", "Year")

norm_topic_prevalence = df_w_topics.select(categories).apply(lambda row: list(row) / sum(list(row)))
norm_columns = [np.array([row[i] for row in norm_topic_prevalence]) for i in range(len(norm_topic_prevalence[0]))]
grouped_columns = [
    norm_columns[0] + norm_columns[4], 
    norm_columns[1] + norm_columns[5], 
    norm_columns[2], 
    norm_columns[3]
]

labels = categories[:4]
for label, column in zip(labels, grouped_columns):
    df_w_topics = df_w_topics.with_column(label, column)
    
prev_topics = df_w_topics.select(["Year"] + labels).group("Year", np.mean)

prev_topics.show()
budget_data.select(0,1,2,3,4).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Year</th> <th>National Defense mean</th> <th>Employment mean</th> <th>Education mean</th> <th>Health Care mean</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>2009</td> <td>0.204423             </td> <td>0.564619       </td> <td>0.0326247     </td> <td>0.198333        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2010</td> <td>0.151898             </td> <td>0.556334       </td> <td>0.0268139     </td> <td>0.264955        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2011</td> <td>0.200403             </td> <td>0.553717       </td> <td>0.0121533     </td> <td>0.233727        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2012</td> <td>0.148673             </td> <td>0.596877       </td> <td>0.00426268    </td> <td>0.250187        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2013</td> <td>0.122074             </td> <td>0.459443       </td> <td>0.0117568     </td> <td>0.406726        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2014</td> <td>0.328809             </td> <td>0.391757       </td> <td>0.00155807    </td> <td>0.277876        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2015</td> <td>0.30705              </td> <td>0.368281       </td> <td>0.00994361    </td> <td>0.314726        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2016</td> <td>0.330559             </td> <td>0.388915       </td> <td>0.00770964    </td> <td>0.272817        </td>
#         </tr>
#     </tbody>
# </table>
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Year</th> <th>National Defense prop</th> <th>Employment prop</th> <th>Education prop</th> <th>Health Care prop</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>2009</td> <td>0.234187             </td> <td>0.372864       </td> <td>0.0226709     </td> <td>0.21731         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2010</td> <td>0.250944             </td> <td>0.415765       </td> <td>0.0371985     </td> <td>0.237398        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2011</td> <td>0.245597             </td> <td>0.403921       </td> <td>0.0280964     </td> <td>0.238175        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2012</td> <td>0.242074             </td> <td>0.406912       </td> <td>0.0256783     </td> <td>0.231424        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2013</td> <td>0.236956             </td> <td>0.431014       </td> <td>0.0210754     </td> <td>0.247823        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2014</td> <td>0.222602             </td> <td>0.431758       </td> <td>0.0258449     </td> <td>0.262723        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2015</td> <td>0.205766             </td> <td>0.421966       </td> <td>0.0330942     </td> <td>0.278835        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2016</td> <td>0.201965             </td> <td>0.413989       </td> <td>0.028834      </td> <td>0.283748        </td>
#         </tr>
#     </tbody>
# </table>

# %%
plt.plot(budget_data['Year'], budget_data['National Defense prop'], lw=2, label='Defense Budget (solid)', color="r")
plt.plot(budget_data['Year'], budget_data['Employment prop'], lw=2, label='Employment Budget (solid)', color="y")
plt.plot(budget_data['Year'], budget_data['Education prop'], lw=2, label='Education Budget (solid)', color="g")
plt.plot(budget_data['Year'], budget_data['Health Care prop'], lw=2, label='Healthcare Budget (solid)', color="b")

plt.plot(prev_topics['Year'], prev_topics['National Defense mean'], '--', lw=2, label='Defense Prevalence (dotted)', color="r")
plt.plot(prev_topics['Year'], prev_topics['Employment mean'], '--', lw=2, label='Employment Prevalence (dotted)', color="y")
plt.plot(prev_topics['Year'], prev_topics['Education mean'], '--', lw=2, label='Education Prevalence (dotted)', color="g")
plt.plot(prev_topics['Year'], prev_topics['Health Care mean'], '--', lw=2, label='Healthcare Prevalence (dotted)', color="b")
plt.xlabel('Years')
plt.ylabel('Prevalance and Budget Proportion')
plt.ylim(-0.1, 0.75)
plt.legend(prop={'size':6});

# %% [markdown]
# ### Findings
#
# Overall, we see that with some degree of error Obama's speeches tend to talk about the topics on the budget with prevelance that is proportional to the actual budget spending done by Congress. However, for each category, there seem to be some notable discrepancies in the budget expenditure that are relevant to our research question. We can split our findings by category:
#
# - **National Defense**: While the budget for national defense has consistently decreased over time, its prevalence seems to spike during and following the election year in which the Republicans took over both the House and the Senate. We also see that the discrepancies are much larger during the years in which the Republicans start to take over Congress as opposed to the inital couple of years when the Democrats primarily had control.
#
#
# - **Employment**: Although the data on employment seems to suggest that Obama had far less discrepancies when the Republicans took over the House and the Senate, we note that the years in which we see an extremely large discrepancy over time occured right after the 2008-2010 recession at the start of Obama's presidency. Therefore, our data might be skewed as a result of this historical event, which explains why it doesn't follow a similar pattern as the rest of the categories.
#
#
# - **Education**: Although Education is rarely referenced during Obama's presidency and the budget for Education is generally extremely small, we see that there is a definite rise in the discrepancy over time as the Republicans took control of the House and Senate.
#
#
# - **Health Care**: We can see a clear spike in the discrepancies in this category during the time the Affordable Care Act was being passed. However, without regarding that particular spike, we still see a that discrepancy tends to increase over time.

# %% [markdown]
# ### Computing Correlation Between The Topic Prevalence In Speeches And Budget Spending
#
# The following code uses the prevalence of a topic in a particular fiscal year and the budget spending in a particular fiscal year as a set of data points and finds the linear correlation (covariance in standard units) between the prevalence of a topic and the budget spending for each category.

# %%
def corr_coefficient(table, column_X, column_Y):
    x = table.column(column_X)
    y = table.column(column_Y)
    x_su = (x-np.mean(x))/np.std(x)
    y_su = (y-np.mean(y))/np.std(y)
    return np.mean(x_su*y_su)

speeches['Year'] = np.array(speeches['Dates'].apply(lambda x: x[:4]))
part1_table = Table().from_df(speeches)
part1_table = part1_table.drop(0, 1)
part1_table = part1_table.group("Year", ",".join)
temp = part1_table.to_df()
temp['Speeches Words'] = np.array(temp['Speeches Tokenized join'].apply(lambda x: x.split()))
temp['Year'] = np.array(temp['Year'].apply(lambda x: int(x)))
test_data = Table().from_df(temp)
test_data["Word Count"] = [len(doc) for doc in test_data["Speeches Words"]]
final_data = test_data.join('Year', budget_data, 'Year').drop(1)
national_defense_word_prop, education_word_prop, healthcare_word_prop, employment_word_prop = [], [], [], []
for year in range(final_data.num_rows):
    words = final_data['Speeches Words'][year]
    num_words_national_defense = len([word for word in words if word in national_defense_words])
    num_words_education = len([word for word in words if word in education_words])
    num_words_healthcare = len([word for word in words if word in health_care_words])
    num_words_employment = len([word for word in words if word in employment_words])
    total_number = num_words_national_defense + num_words_education + num_words_healthcare + num_words_employment
    national_defense_word_prop += [num_words_national_defense / total_number]
    education_word_prop += [num_words_education / total_number]
    healthcare_word_prop += [num_words_healthcare / total_number]
    employment_word_prop += [num_words_employment / total_number]
observation_table = Table().with_columns('Year', np.arange(2009, 2017),
                                         'National defense word prop',  national_defense_word_prop,
                                         'Education word prop', education_word_prop,
                                         'Health Care word prop', healthcare_word_prop,
                                         'Employment word prop', employment_word_prop).join('Year', budget_data.select(0,1,2,3,4), 'Year')
observation_table = observation_table.select(0,1,4,2,3,5,6,7,8)
ff, pp = plt.subplots(2, 2)
pp[0, 0].scatter(observation_table[1], observation_table[5], lw=2, label='Defense', s=70)
m1, b1 = np.polyfit(observation_table[1], observation_table[5], 1)
pp[0, 0].plot(np.append(observation_table[1], [min(observation_table[1])-0.1, max(observation_table[1])+0.1]), 
              m1*(np.append(observation_table[1], [min(observation_table[1])-0.1, max(observation_table[1])+0.1])) + b1,
              '-', alpha = 0.5)
r1 = round(corr_coefficient(observation_table, 1, 5),2)
pp[0, 0].set_title('Defense, r:' + str(r1))
plt.xlabel('Prevalence')
plt.ylabel('Budget Proportion')

pp[0, 1].scatter(observation_table[2], observation_table[6], lw=2, label='Employment', s=70)
m2, b2 = np.polyfit(observation_table[2], observation_table[6], 1)
pp[0, 1].plot(np.append(observation_table[2], [min(observation_table[2])-0.1, max(observation_table[2])+0.1]), 
              m2*(np.append(observation_table[2], [min(observation_table[2])-0.1, max(observation_table[2])+0.1])) + b2, 
              '-', alpha = 0.5)
r2 = round(corr_coefficient(observation_table, 2, 6),2)
pp[0, 1].set_title('Employment, r:' + str(r2))
plt.xlabel('Prevalence')
plt.ylabel('Budget Proportion')

pp[1, 0].scatter(observation_table[3], observation_table[7], lw=2, label='Education', s=70, alpha = 0.9)
m3, b3 = np.polyfit(observation_table[3], observation_table[7], 1)
pp[1, 0].plot(np.append(observation_table[3], [min(observation_table[3])-0.05, max(observation_table[3])+0.05]), 
              m3*(np.append(observation_table[3], [min(observation_table[3])-0.05, max(observation_table[3])+0.05])) + b3, 
              '-', alpha = 0.5)
r3 = round(corr_coefficient(observation_table, 3, 7), 2)
pp[1, 0].set_title('Education, r:' + str(r3))
plt.xlabel('Prevalence')
plt.ylabel('Budget Proportion')

pp[1, 1].scatter(observation_table[4], observation_table[8], lw=2, label='Healthcare', s=70)
m4, b4 = np.polyfit(observation_table[4], observation_table[8], 1)
pp[1, 1].plot(np.append(observation_table[4], [min(observation_table[4])-0.05, max(observation_table[4])+0.05]), 
              m4*(np.append(observation_table[4], [min(observation_table[4])-0.05, max(observation_table[4])+0.05])) + b4,
              '-', alpha = 0.5)
r4 = round(corr_coefficient(observation_table, 4, 8),2)
pp[1, 1].set_title('Healthcare, r:' + str(r4))
ff.set_figheight(15)
ff.set_figwidth(15)
ff.subplots_adjust(hspace=0.3)
pp[0, 0].set_xlabel('Prevalence')
pp[0, 0].set_ylabel('Budget Proportion')
pp[1, 0].set_xlabel('Prevalence')
pp[1, 0].set_ylabel('Budget Proportion')
pp[0, 1].set_xlabel('Prevalence')
pp[0, 1].set_ylabel('Budget Proportion')
pp[1, 1].set_xlabel('Prevalence')
pp[1, 1].set_ylabel('Budget Proportion')
plt.show();

# %% [markdown]
# ### Findings
#
# We can split our findings by category:
#
# - National Defense: We see that the expenditure on National Defense has a negative correlation with the prevalence of National Defense in President Obama's speeches. In other words, this tells us that the more that Obama talked about National Defense, the less the budget is being spent on National Defense. To our prior knowledge, we know that Obama has been a big advocate of reducing military spending by withdrawing troops from foreign countries; therefore, this data seems to support the fact that overall Obama was successful at convincing Congress to reduce National Defense Spending.
#
# - Employment: As noted in the findings of our by-the-year analysis, although this data seems to suggest that Obama's speeches had a negative impact on budget expenditure, our data might be skewed as a result of the economic recession that increased the amount of prevalence of Employment in his speeches, which explains why our correlation seems to indicate an inconsistency.
#
# - Education: Since the magnitude of the correlation coefficient is less than 0.5, there is a weak correlation between the prevalence of Education and Education expenditure that could have been due to random chance. Therefore, we don't have evidence to conclude anything; we will later conduct a hypothesis test that ends up with a similar result.
#
# - Health Care: As in the case of National Defense, we see that President Obama's general direction (pro-Health Care expenditure) seems to follow along with the correlation that we observe. Therefore, it seems to be that overall Obama was successful in convincing Congress to increase Health Care Spending.

# %% [markdown]
# ### Hypothesis Testing:
#
# **Statistical Method**: Wilcoxen Signed-rank test (the non-parametric version of a paired t-test)
#
# **Assumptions**:
# - Each year's word proportion and budget proportion is paired and comes from the same population.
# - Each pair is chosen randomly and independently.
# - The proportions are measured on a continuous ordinal scale.
#
# **Null**: For each category, it is **equally likely** that a randomly selected proportions of words under that category found in Obama's speeches will be less than or greater than a randomly selected proportions of that category's GDP expenditure for each year. Any deviation is due to chance. The political interest under Obama's administration expressed in the president's speech is **consistent** with Congress's actions in terms of expenditure. **The p-value is greater than 5%.**
#
# **Alternative**: For each category, it is **NOT equally likely** that a randomly selected proportions of words under that category found in Obama's speeches will be less than or greater than a randomly selected proportions of that category's GDP expenditure for each year. The difference is NOT due to chance, but in fact, other factors. The political interest under Obama's administration expressed in the president's speech is **inconsistent** with Congress's actions in terms of expenditure. **The p-value is less than 5%.**
#
# **Test Statistic**: $W$, which is the sum of signed ranks.

# %%
test_table = observation_table.select(0)
test_table['National Defense Prop Diff'] = observation_table.column(1) - observation_table.column(5)
test_table['Employment Prop Diff'] = observation_table.column(2) - observation_table.column(6)
test_table['Education Prop Diff'] = observation_table.column(3) - observation_table.column(7)
test_table['Health Care Prop Diff'] = observation_table.column(4) - observation_table.column(8)
test_table.show()
wilcox_results = Table().with_column('Category', ['National Defense', 'Employment', 'Education', 'Health Care'])
test_statistic = make_array()
p_values = make_array()
rejects = make_array()
for i in np.arange(1, 5):
    w, pval = scipy.stats.wilcoxon(test_table.column(i))
    reject = str(pval < 0.05)
    test_statistic = np.append(test_statistic, w)
    p_values = np.append(p_values, pval)
    rejects = np.append(rejects, reject)
wilcox_results['Test Statistic($W$)'], wilcox_results['P-Value'], wilcox_results['Reject Null'] = test_statistic, p_values, rejects
wilcox_results.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Year</th> <th>National Defense Prop Diff</th> <th>Employment Prop Diff</th> <th>Education Prop Diff</th> <th>Health Care Prop Diff</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>2009</td> <td>-0.0242378                </td> <td>-0.0669406          </td> <td>0.166073           </td> <td>0.0780726            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2010</td> <td>-0.0774669                </td> <td>-0.119005           </td> <td>0.113964           </td> <td>0.141203             </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2011</td> <td>-0.019283                 </td> <td>-0.0986655          </td> <td>0.156176           </td> <td>0.045984             </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2012</td> <td>-0.050318                 </td> <td>-0.113383           </td> <td>0.140894           </td> <td>0.116718             </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2013</td> <td>-0.0274236                </td> <td>-0.209415           </td> <td>0.134701           </td> <td>0.16527              </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2014</td> <td>0.0552776                 </td> <td>-0.244974           </td> <td>0.116346           </td> <td>0.130422             </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2015</td> <td>0.0806382                 </td> <td>-0.238793           </td> <td>0.13365            </td> <td>0.0848437            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2016</td> <td>0.0335551                 </td> <td>-0.231257           </td> <td>0.128668           </td> <td>0.140498             </td>
#         </tr>
#     </tbody>
# </table>
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Category</th> <th>Test Statistic($W$)</th> <th>P-Value</th> <th>Reject Null</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>National Defense</td> <td>18                 </td> <td>1        </td> <td>False      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Employment      </td> <td>0                  </td> <td>0.0117187</td> <td>True       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Education       </td> <td>0                  </td> <td>0.0117187</td> <td>True       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Health Care     </td> <td>0                  </td> <td>0.0117187</td> <td>True       </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ### Conclusion:
#
# Since the p-value is less than the cutoff point at 5% for categories **Employment, Education, and Health Care**, we claim the result statistically significant and we **reject the null hypothesis** and conclude that it is **NOT equally likely** that a randomly selected proportions of words under Employment, Education, and Health Care found in Obama's speeches will be less than or greater than a randomly selected proportions of Employment, Education, and Health Care's GDP expenditure for each year. The difference is NOT due to chance, but in fact, other factors. The political interest under Obama's administration expressed in the president's speech is **inconsistent** with Congress's actions in terms of expenditure for **3 out of 4** categories.
#
# Even though there is an overall inconsistency, how correlated are Obama's words with the allocation of budget? We will take a closer look at each category to further determine our results.

# %% [markdown]
# ### One Step Further
#
# Since we see that there is a minor discrepancy in the proportions of words and budget for the 4 categories combined, we want to whether there is a discrepancy (dependency) in each individual category. We will conduct a hypothesis testing for each category.
#
# For each category, the hypotheses are the same:
#
# **Null**: There is no linear correlation between the disrtibution of the proportion of words under the category found in Obama's speeches and the distribution of the proportion of the category's GDP expenditure for each year. The two proportion distributions are independent. Any deviation is due to chance. For this category, the political interest under Obama's administration expressed in the president's speech is independent of Congress's actions in terms of expenditure. **Correlation Coefficient (r) = 0**.
#
# **Alternative**: There is a linear correlation between the disrtibution of the proportion of words under the category found in Obama's speeches and the distribution of the proportion of the category's GDP expenditure for each year. The two proportion distributions are not independent. Any deviation is NOT due to chance. For this category, the political interest under Obama's administration expressed in the president's speech is correlated with Congress's actions in terms of expenditure. **Correlation Coefficient (r) != 0**.
#
# **Test Statistic**: Correlation Coefficient (r)

# %% [markdown]
# ### National Defense

# %%
# bootstrap
def bootstrap_test(name, r, c):
    test_statistics = []
    for trial in range(3000):
        new_sample = observation_table.select(r, c).sample()
        test_statistics += [corr_coefficient(new_sample, 0, 1)]
    left, right = np.percentile(test_statistics, 2.5), np.percentile(test_statistics, 97.5)
    Table().with_column(name, test_statistics).hist()
    plt.plot(make_array(left, right), make_array(0, 0), color='r', lw=9)
    return [left, right]

# %%
bootstrap_test('Test Statistic for National Defense', 1, 5)
# Out:
# [-0.99023736452785571, -0.40514673086013986]

# %% [markdown]
# ### Conclusion for National Defense:
#
# Since 0 is not contained in the 95% confidence interval, we reject the null and conclude that there **is** a linear correlation between the disrtibution of the proportion of words under National Defense found in Obama's speeches and the distribution of the proportion of National Defense's GDP expenditure for each year. The two proportion distributions are not independent. Any deviation is NOT due to chance. **For National Defense, the political interest under Obama's administration expressed in the president's speech is correlated with Congress's actions in terms of expenditure.**

# %% [markdown]
# ### Employment

# %%
bootstrap_test('Test Statistic for Employment', 2, 6)
# Out:
# [-0.92888391904579648, -0.33387673026449105]

# %% [markdown]
# ### Conclusion for Employment:
#
# Since 0 is not contained in the 95% confidence interval, we reject the null and conclude that there **is** a linear correlation between the disrtibution of the proportion of words under Employment found in Obama's speeches and the distribution of the proportion of Employment's GDP expenditure for each year. The two proportion distributions are not independent. Any deviation is NOT due to chance. **For Employment, the political interest under Obama's administration expressed in the president's speech is correlated with Congress's actions in terms of expenditure.**

# %% [markdown]
# ### Education

# %%
bootstrap_test('Test Statistic for Education', 3, 7)
# Out:
# [-0.85201078871659686, 0.47298961365162162]

# %% [markdown]
# ### Conclusion for Education:
#
# Since 0 is contained in the 95% confidence interval, we **fail to reject** the null and conclude that there **is not** a linear correlation between the disrtibution of the proportion of words under Education found in Obama's speeches and the distribution of the proportion of Education's GDP expenditure for each year. The two proportion distributions are independent. Any deviation is due to chance. **For Education, the political interest under Obama's administration expressed in the president's speech is independent of Congress's actions in terms of expenditure.**

# %% [markdown]
# ### Healthcare

# %%
bootstrap_test('Test Statistic for Healthcare', 4, 8)
# Out:
# [0.14661367094844152, 0.92835868762108753]

# %% [markdown]
# ### Conclusion for Healthcare:
#
# Since 0 is not contained in the 95% confidence interval, we reject the null and conclude that there **is** a linear correlation between the disrtibution of the proportion of words under Healthcare found in Obama's speeches and the distribution of the proportion of Healthcare's GDP expenditure for each year. The two proportion distributions are not independent. Any deviation is NOT due to chance. **For Healthcare, the political interest under Obama's administration expressed in the president's speech is correlated with Congress's actions in terms of expenditure.**

# %% [markdown]
# ### Findings:
#
# From our results of Hypothesis Testing, we see that besides Education, there is a some sort of linear correlation between the proportions of words and budget for the following categories:
#
# - National Defense
# - Employment
# - Healthcare
#
# This is consistent with our findings during our correlation-coefficient analysis.

# %% [markdown]
# ### Measuring The Effect Of Party Majorities Within Congress On Observed Discrepancies
#
# The following code groups our data according to the distinct periods of Congressional control during Obama's administration, as expressed in the research proposal.

# %%
periods_table = final_data.select(0,1,7,8,9,10,11)
periods_table['Period'] = [1, 1, 1, 2, 2, 2, 3, 3]
period1 = final_data.where('Year', are.between_or_equal_to(2009, 2011))
period2 = final_data.where('Year', are.between_or_equal_to(2012, 2014))
period3 = final_data.where('Year', are.between_or_equal_to(2015, 2016))
period1_speeches, period2_speeches, period3_speeches= [], [], []
for i in range(3):
    period1_speeches = np.append(period1_speeches, period1.column(1)[i])
    period2_speeches = np.append(period2_speeches, period2.column(1)[i])
for i in range(2):
    period3_speeches = np.append(period3_speeches, period3.column(1)[i])
part2_table = periods_table.group('Period', collect = np.sum).with_column('Speeches', 
                                                            [period1_speeches, period2_speeches, period3_speeches])
part2_table['National Defense Prop'] = part2_table['National Defense sum'] / part2_table['Total federal outlay sum']
part2_table['Employment Prop'] = part2_table['Employment/Social_Security sum'] / part2_table['Total federal outlay sum']
part2_table['Education Prop'] = part2_table['Education sum'] / part2_table['Total federal outlay sum']
part2_table['Healthcare Prop'] = part2_table['Health sum'] / part2_table['Total federal outlay sum']
national_defense_word_prop2, education_word_prop2, healthcare_word_prop2, employment_word_prop2 = [], [], [], []
for period in range(part2_table.num_rows):
    words2 = part2_table['Speeches'][period]
    num_words_national_defense2 = len([word for word in words2 if word in national_defense_words])
    num_words_education2 = len([word for word in words2 if word in education_words])
    num_words_healthcare2 = len([word for word in words2 if word in health_care_words])
    num_words_employment2 = len([word for word in words2 if word in employment_words])
    total_number2 = num_words_national_defense2 + num_words_education2 + num_words_healthcare2 + num_words_employment2
    national_defense_word_prop2 += [num_words_national_defense2 / total_number2]
    education_word_prop2 += [num_words_education2 / total_number2]
    healthcare_word_prop2 += [num_words_healthcare2 / total_number2]
    employment_word_prop2 += [num_words_employment2 / total_number2]
part2_table['National Defense Word Prop'] = national_defense_word_prop2
part2_table['Employment Word Prop'] = employment_word_prop2
part2_table['Education Word Prop'] = education_word_prop2
part2_table['Healthcare Word Prop'] = healthcare_word_prop2
observation_period_table = part2_table.select(0,9,10,11,12,13,14,15,16)
observation_period_table['National Defense Abs Prop Diff'] = abs(observation_period_table['National Defense Prop'] 
                                                                 - observation_period_table['National Defense Word Prop'])
observation_period_table['Employment Abs Prop Diff'] = abs(observation_period_table['Employment Prop'] 
                                                                 - observation_period_table['Employment Word Prop'])
observation_period_table['Education Abs Prop Diff'] = abs(observation_period_table['Education Prop']
                                                                 - observation_period_table['Education Word Prop'])
observation_period_table['Healthcare Abs Prop Diff'] = abs(observation_period_table['Healthcare Prop'] 
                                                                 - observation_period_table['Healthcare Word Prop']) 
observation_period_table = observation_period_table.select(0,9,10,11,12)

average_abs_prop_diff = []
for i in range(3):
    average_abs_prop_diff = np.append(average_abs_prop_diff, np.average(observation_period_table.drop(0).row(i)))
Table().with_columns(
    'Period', ['2009-2011 Democrats', '2012-2014 Mixed', '2015-2016 Republicans'],
    "Average Discrepancy Between Speeches and Budget", average_abs_prop_diff).barh('Period')

# %% [markdown]
# ### Findings
# We clearly see that as the Republicans take control of Congress, the amount of discrepancy between Obama's speeches and the Congressional budget expenditure increases.

# %% [markdown]
# ## Summary
#
# We found that the agenda of administration in charge of the executive branch is overall inconsistent with the actions of the legislative branch during Obama's presidency. However, when analyzing by category, we found strong correlations between prevalence and budget allocation for National Defense, Employment, and Healthcare, this result seems to suggest that Obama's speeches had a potential effect or influence on the allocation of budget by the Congress.
#
# First, we saw that order of the magnitude of the prevalence of topics expressed in Obama's speeches is roughly similar to that of the budget expenditure of each category, with some inconsistency. Then, when we plotted the prevalence over time with the proportions of budget expenditure for each category, we noticed discrepancies in but the budget proportions lined up well overall with the their respective topic prevalences.
#
# We used hypothesis testing to test the statement that the political interest under Obama's administration expressed in the president's speech is consistent with Congress's actions in terms of expenditure and decided to reject it based on the results of the test. However, when we took this one step further by computing the correlations for each category, we noticed high correlations between the prevalence of topics and their respective budget proportions in $3$ out of $4$ categories. This result suggests Obama's speeches might have had an influence on the Congress's allocation of budget.
#
# In addition, we found that the different political affiliations between the legislative and executive branches seems to be correlated with a discrepancy between the agenda of the executive branch and the actions, specifically in regards to budget allocation, of the legislative branch, as we saw in the final analysis between the three distinct time periods in Obama's presidency that the average discrepancy across 4 categories increased as the Congress became more and more controlled by Republicans.
#
# Overall, this study seems to suggest a broader political issue in our current society today. It suggests that, during Obama's administration, there is a discrepancy between the agenda of the executive branch, expressed in Obama's speeches, and the budget allocations determined by Congress. This could be a long-standing issue since often policies that are advocated and administered by the executive branch require the legislative branch to provide adequate and necessary funding at the proportions implied and such a discrepancy could cause less effective implementations of policies framed by the executive branch. Furthermore, our study seems to also suggest that differences in political affiliation can play a large role in increasing such discrepancies; in other words, the rivalry of political parties could play a heavy role in creating a less effective government as a whole. This study, in some sense, puts truth into our first president concerns against political parties causing a partisan government as a whole.
